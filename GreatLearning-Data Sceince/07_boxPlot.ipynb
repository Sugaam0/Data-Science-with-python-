# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
one = [1,2,3,4,5,6,7,8,9]
two = [1,2,3,4,5,4,3,2,1]
three = [6,7,8,9,8,7,6,7,8]

data = [one, two, three]
data
# Out:
# [[1, 2, 3, 4, 5, 6, 7, 8, 9],
#  [1, 2, 3, 4, 5, 4, 3, 2, 1],
#  [6, 7, 8, 9, 8, 7, 6, 7, 8]]

# %%
plt.boxplot(data)
plt.show()

# %%
plt.violinplot(data, showmedians=True)
plt.show()
